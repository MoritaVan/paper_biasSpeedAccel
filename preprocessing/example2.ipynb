])

# %%
param_noNAN = [{'name': 'steady_state', 'value': 5.5, 'min': 3.0, 'max': 40.0, 'vary': True}, 
               {'name': 'target_dir', 'value': 1.0, 'min': None, 'max': None, 'vary': False}, 
               {'name': 'fit_baseline', 'value': True, 'min': None, 'max': None, 'vary': False}, 
               {'name': 'anti_slope_tmp', 'value': 6.797084895508421, 'min': -40.0, 'max': 40.0, 'vary': 'vary'}, 
               {'name': 'anti_slope', 'expr': 'anti_slope_tmp if abs(anti_slope_tmp) >= .5 else 0'}, 
               {'name': 'anti_offset', 'value': 90, 'min': 30, 'max': 120, 'vary': True}, 
               {'name': 'anti_onset_tmp', 'value': -100, 'min': -350, 'max': 0, 'vary': 'vary'}, 
               {'name': 'anti_onset', 'expr': 'anti_onset_tmp if anti_slope != 0 else anti_offset-1'}, 
               {'name': 'pursuit_slope', 'value': 80, 'min': 3.0, 'max': 500.0, 'vary': 'vary'}, 
               {'name': 'baseline', 'value': 0, 'min': -1, 'max': 1, 'vary': True}, 
               {'name': 'horizontal_shift', 'value': 100, 'min': 0, 'max': 110, 'vary': True}]
param_NAN   = [{'name': 'steady_state', 'value': 5.5, 'min': 3.0, 'max': 40.0, 'vary': True}, 
               {'name': 'target_dir', 'value': 1.0, 'min': None, 'max': None, 'vary': False}, 
               {'name': 'fit_baseline', 'value': True, 'min': None, 'max': None, 'vary': False}, 
               {'name': 'anti_slope_tmp', 'value': 10.1555458391051, 'min': -40.0, 'max': 40.0, 'vary': 'vary'}, 
               {'name': 'anti_slope', 'expr': 'anti_slope_tmp if abs(anti_slope_tmp) >= .5 else 0'}, 
               {'name': 'anti_offset', 'value': 90, 'min': 30, 'max': 120, 'vary': True}, 
               {'name': 'anti_onset_tmp', 'value': -100, 'min': -350, 'max': 0, 'vary': 'vary'}, 
               {'name': 'anti_onset', 'expr': 'anti_onset_tmp if anti_slope != 0 else anti_offset-1'}, 
               {'name': 'pursuit_slope', 'value': 80, 'min': 3.0, 'max': 500.0, 'vary': 'vary'}, 
               {'name': 'baseline', 'value': 0, 'min': -1, 'max': 1, 'vary': True}, 
               {'name': 'horizontal_shift', 'value': 100, 'min': 0, 'max': 110, 'vary': True}]

# %%
def velocity_ExponentialAnti_SigmoidalPursuit(x, target_dir, baseline, anti_onset, anti_slope, anti_offset, pursuit_slope, horizontal_shift, steady_state, fit_baseline:bool=False) :

    '''
    Model of eye-velocity over time, in a smooth pursuit task. 
    Anticipatory phase is modeled as an exponential, and initial visually guided pursuit as a sigmoid

    Parameters
    ----------
    x : ndarray
        time in milliseconds
    target_dir : int
        direction of the target 
        -1 (corresponding usually to left/down) or 1 (corresponding usually to right/up)
    anti_onset : int
        anticipation onset in milliseconds
    anti_slope : float
        defines the slope of the exponential corresponding to the anticipatory phase
    anti_offset : int
        offset of the anticipatory phase in milliseconds
    pursuit_slope : float
        defines the slope of the sigmoid corresponding to the initial phase of the visually-guided pursuit
    horizontal_shift : int
        shift in the sigmoid function corresponding to the initial phase of the visually-guided pursuit
    steady_state : float
        eye velocity reached in the late phase of visually-guided pursuit (in degrees/sec)
    fit_baseline : bool
        if ``True``, fits a flat regression corresponding to the baseline velocity
        this parameter is intended to be used when there were problems with the eye-tracker calibration, 
        such that eye velocity is not centered in zero during the fixation phase

    Returns
    -------
    velocity : list
        model of the eye velocity in deg/sec
    '''

    if not fit_baseline:      baseline = 0

    anti_sign     = np.sign(anti_slope)
    anti_slope    = abs(anti_slope)/1000 # to switch from deg/sec to deg/ms
    pursuit_slope = target_dir*pursuit_slope/1000
    steady_state  = steady_state*target_dir
    anti_onset    = np.floor(anti_onset)
    anti_offset   = np.floor(anti_offset)
    time          = np.arange(x[0], x[-1]+1, 1)

    idx_baseline     = np.where(time < anti_onset)[0]
    idx_anticipation = np.where((time >= anti_onset)&(time < anti_offset))[0]
    idx_pursuit      = np.where(time >= anti_offset)[0]
        
    x_anticipation = np.arange(0,len(idx_anticipation),1)
    x_pursuit      = np.arange(0,len(idx_pursuit),1)

    velocity = np.zeros(len(time))
    velocity[idx_baseline]     = baseline * np.ones(len(idx_baseline))
    velocity[idx_anticipation] = baseline + anti_sign*(np.exp(anti_slope*x_anticipation)-1)

    max_anticipation      = anti_sign*max(abs(velocity))
    sigmoid_pursuit       = (steady_state-max_anticipation)/(1 + np.exp(-pursuit_slope*(x_pursuit-horizontal_shift)))
    velocity[idx_pursuit] = max_anticipation + sigmoid_pursuit - sigmoid_pursuit[0]

    missing_data = list(set(time)-set(x))

    if len(missing_data):
        return velocity[~np.isin(time,missing_data)]
    else:
        return velocity

# %%
model = Model(velocity_ExponentialAnti_SigmoidalPursuit, independent_vars=['x'])
indep_vars = {
    'x':x
}

# %%
params = Parameters()
for num_par in range(len(param_noNAN)) :
    if 'expr' in param_noNAN[num_par].keys() :
        params.add(param_noNAN[num_par]['name'], expr=param_noNAN[num_par]['expr'])
    else :
        if param_noNAN[num_par]['vary'] == 'vary' : var = False
        else :                                    var = param_noNAN[num_par]['vary']
        params.add(param_noNAN[num_par]['name'],
                    value=param_noNAN[num_par]['value'],
                    min=param_noNAN[num_par]['min'],
                    max=param_noNAN[num_par]['max'],
                    vary=var)


out = model.fit(trial_noNAN, params, nan_policy='omit', **indep_vars)

# make the other parameters vary now
for num_par in range(len(param_noNAN)) :
    if 'vary' in param_noNAN[num_par].keys() :
        if param_noNAN[num_par]['vary'] == 'vary' :
            out.params[param_noNAN[num_par]['name']].set(vary=True)

# result_deg = model.fit(data_trial, out.params, method='nelder', nan_policy='omit', **indep_vars)
result_noNAN = model.fit(trial_noNAN, out.params, method='powell', nan_policy='omit', **indep_vars)

# %%
params = Parameters()
for num_par in range(len(param_NAN)) :
    if 'expr' in param_NAN[num_par].keys() :
        params.add(param_NAN[num_par]['name'], expr=param_NAN[num_par]['expr'])
    else :
        if param_NAN[num_par]['vary'] == 'vary' : var = False
        else :                                    var = param_NAN[num_par]['vary']
        params.add(param_NAN[num_par]['name'],
                    value=param_NAN[num_par]['value'],
                    min=param_NAN[num_par]['min'],
                    max=param_NAN[num_par]['max'],
                    vary=var)
        
out = model.fit(trial_NAN, params, nan_policy='omit', **indep_vars)

# make the other parameters vary now
for num_par in range(len(param_NAN)) :
    if 'vary' in param_NAN[num_par].keys() :
        if param_NAN[num_par]['vary'] == 'vary' :
            out.params[param_NAN[num_par]['name']].set(vary=True)

# result_deg = model.fit(data_trial, out.params, method='nelder', nan_policy='omit', **indep_vars)
result_NAN = model.fit(trial_NAN, out.params, method='powell', nan_policy='omit', **indep_vars)

# %%
print(result_NAN.fit_report())
# Out:
# [[Model]]
#     Model(velocity_ExponentialAnti_SigmoidalPursuit)
# [[Fit Statistics]]
#     # fitting method   = Powell
#     # function evals   = 1264
#     # data points      = 515
#     # variables        = 7
#     chi-square         = 106.801874
#     reduced chi-square = 0.21023991
#     Akaike info crit   = -796.193584
#     Bayesian info crit = -766.484416
#     R-squared          = 0.95064176
# ##  Warning: uncertainties could not be estimated:
#     this fitting method does not natively calculate uncertainties
#     and numdifftools is not installed for lmfit to do this. Use
#     `pip install numdifftools` for lmfit to estimate uncertainties
#     with this fitting method.
# [[Variables]]
#     steady_state:      3.00031177 (init = 3.405705)
#     target_dir:        1 (fixed)
#     fit_baseline:      1 (fixed)
#     anti_slope_tmp:    8.67462899 (init = 10.15555)
#     anti_slope:        8.67462899 == 'anti_slope_tmp if abs(anti_slope_tmp) >= .5 else 0'
# ...

# %%
print(result_noNAN.fit_report())
# Out:
# [[Model]]
#     Model(velocity_ExponentialAnti_SigmoidalPursuit)
# [[Fit Statistics]]
#     # fitting method   = Powell
#     # function evals   = 665
#     # data points      = 701
#     # variables        = 7
#     chi-square         = 137.349447
#     reduced chi-square = 0.19790987
#     Akaike info crit   = -1128.61563
#     Bayesian info crit = -1096.74808
#     R-squared          = 0.96432066
# ##  Warning: uncertainties could not be estimated:
#     this fitting method does not natively calculate uncertainties
#     and numdifftools is not installed for lmfit to do this. Use
#     `pip install numdifftools` for lmfit to estimate uncertainties
#     with this fitting method.
# [[Variables]]
#     steady_state:      5.51811882 (init = 5.568646)
#     target_dir:        1 (fixed)
#     fit_baseline:      1 (fixed)
#     anti_slope_tmp:    7.22644777 (init = 6.797085)
#     anti_slope:        7.22644777 == 'anti_slope_tmp if abs(anti_slope_tmp) >= .5 else 0'
# ...

# %%
f = plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
plt.plot(trial_NAN[~np.isnan(trial_NAN)], color='blue', label='data_NAN')
plt.plot(result_NAN.eval(), color='red', label='eval_NAN')
ax = plt.subplot(1,3,2)
plt.plot(trial_NAN, color='blue', label='data_NAN')
plt.plot(result_NAN.eval(x=x), color='red', label='eval_NAN')
ax = plt.subplot(1,3,3)
result_NAN.plot_fit(ax=ax)
# Out:
# <Axes: title={'center': 'Model(velocity_ExponentialAnti_SigmoidalPursuit)'}, xlabel='x', ylabel='y'>

# %%
f = plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
plt.plot(trial_noNAN, color='blue', label='data_noNAN')
plt.plot(result_noNAN.eval(), color='red', label='eval_noNAN')
ax = plt.subplot(1,2,2)
result_noNAN.plot_fit(ax=ax)
# Out:
# <Axes: title={'center': 'Model(velocity_ExponentialAnti_SigmoidalPursuit)'}, xlabel='x', ylabel='y'>
